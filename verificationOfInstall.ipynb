# %%
import torch

# %%
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version (torch):", torch.version.cuda)

if torch.cuda.is_available():
    i = torch.cuda.current_device()
    print("Current device id:", i)
    print("Device name:", torch.cuda.get_device_name(i))
    print("Device capability:", torch.cuda.get_device_capability(i))
    print("cuDNN enabled:", torch.backends.cudnn.enabled)
    print("cuDNN version:", torch.backends.cudnn.version())
# Out:
# Torch version: 2.10.0+cu126
# CUDA available: True
# CUDA version (torch): 12.6
# Current device id: 0
# Device name: NVIDIA GeForce GTX 1650
# Device capability: (7, 5)
# cuDNN enabled: True
# cuDNN version: 91002

# %%
print(torch.rand(5, 3))
# Out:
# tensor([[0.4865, 0.4651, 0.0505],
#         [0.3098, 0.9380, 0.7493],
#         [0.2793, 0.4019, 0.1623],
#         [0.5062, 0.7517, 0.6436],
#         [0.4336, 0.2606, 0.0909]])

# %%
# !nvidia-smi
# Out:
# Wed Feb  4 17:07:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.22                 Driver Version: 552.22         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   52C    P8              3W /   50W |     816MiB /   4096MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2684    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A      4652    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A      5160    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A      5840    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A      6732    C+G   ...64__cv1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A      7360    C+G   D:\Tool\PixPin\PixPin.exe                   N/A      |
# |    0   N/A  N/A      8652    C+G   ...on\wallpaper_engine\wallpaper32.exe      N/A      |
# |    0   N/A  N/A     10368    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13116    C+G   ...on\144.0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     13240    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13284    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     15372    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     19436    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     19892    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     20012    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     21044    C+G   ...on\144.0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     22368    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     23276    C+G   D:\Tool\eudic\eudic.exe                     N/A      |
# |    0   N/A  N/A     24252    C+G   D:\DevTools\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A     24916    C+G   ...7\extracted\runtime\WeChatAppEx.exe      N/A      |
# |    0   N/A  N/A     25508    C+G   ..._x64__2p2nqsd0c76g0\app\ChatGPT.exe      N/A      |
# |    0   N/A  N/A     26460    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import sys
print("Python:", sys.version)
print(sys.executable)

try:
    import cv2
    print("opencv-python:", cv2.__version__)
except Exception as e:
    print("opencv-python: not installed", e)

try:
    import torch
    print("PyTorch:", torch.__version__)
except Exception as e:
    print("PyTorch: not installed", e)

try:
    import torchvision
    print("torchvision:", torchvision.__version__)
except Exception as e:
    print("torchvision: not installed", e)
# Out:
# Python: 3.10.4 (tags/v3.10.4:9d38120, Mar 23 2022, 23:13:41) [MSC v.1929 64 bit (AMD64)]
# e:\Courses\Winter 2026\ECE 740 B04\Project\.venv\Scripts\python.exe
# opencv-python: 4.13.0
# PyTorch: 2.10.0+cu126
# torchvision: 0.25.0+cu126
